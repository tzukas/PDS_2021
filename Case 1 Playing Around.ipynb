# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
energy_df = pd.read_csv("CASE1/data/ENEXIS.csv")

# %%
energy_df
# Out:
#         Unnamed: 0                street zipcode_from zipcode_to       city  \
# 0                0               Sasdijk       4251AB     4251AB  WERKENDAM
# 1                1               Sasdijk       4251AC     4251AC  WERKENDAM
# 2                2               Sasdijk       4251AD     4251AD  WERKENDAM
# 3                3             Nieuweweg       4251AE     4251AG  WERKENDAM
# 4                4             Koppenhof       4251AH     4251AH  WERKENDAM
# ...            ...                   ...          ...        ...        ...
# 455918      124581  Jacob Tilbusscherweg       9998XB     9998XB  ROTTUM GN
# 455919      124582           Jan Boerweg       9998XC     9998XD  ROTTUM GN
# 455920      124583               Knolweg       9998XE     9999XG  ROTTUM GN
# 455921      124584        Stitswerderweg       9999XH     9999XJ  STITSWERD
# 455922      124585                 Stiel       9999XK     9999XL  STITSWERD
#
# ...

# %%
energy_df.drop("Unnamed: 0", axis=1)
# Out:
#                       street zipcode_from zipcode_to       city  \
# 0                    Sasdijk       4251AB     4251AB  WERKENDAM
# 1                    Sasdijk       4251AC     4251AC  WERKENDAM
# 2                    Sasdijk       4251AD     4251AD  WERKENDAM
# 3                  Nieuweweg       4251AE     4251AG  WERKENDAM
# 4                  Koppenhof       4251AH     4251AH  WERKENDAM
# ...                      ...          ...        ...        ...
# 455918  Jacob Tilbusscherweg       9998XB     9998XB  ROTTUM GN
# 455919           Jan Boerweg       9998XC     9998XD  ROTTUM GN
# 455920               Knolweg       9998XE     9999XG  ROTTUM GN
# 455921        Stitswerderweg       9999XH     9999XJ  STITSWERD
# 455922                 Stiel       9999XK     9999XL  STITSWERD
#
#         num_connections  annual_consume  annual_consume_lowtarif_perc  \
# 0                    16         4282.00                         25.00
# ...
